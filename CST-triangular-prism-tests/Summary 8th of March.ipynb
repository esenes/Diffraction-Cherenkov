# %% [markdown]
# # Summary of the CST simulations
#
# Upodated at 8th of March

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pnd
import glob

# %%
fpath = '/Users/esenes/work/Diffraction-Cherenkov/CST-triangular-prism-tests/'
folders = ['prism_10mm_side_50mm_behind_7cell/','prism_20mm_side_25mmbehind_50mmfront_7cell/','prism_20mm_side_25mmbehind_7cell/','prism_20mm_side_50mmbehind_7cell/','prism_20mm_side_50mmbehind_7cell-1.5mm/','prism_20mm_side_50mmbehind_7cell-n1.5mm/']
field_path = 'Probe Signals/'

# time domain filenames
f_comp = ['E-Field (-75 0 0)(Abs) (pb).txt','E-Field (-75 0 0)(X) (pb).txt','E-Field (-75 0 0)(Y) (pb).txt','E-Field (-75 0 0)(Z) (pb).txt','E-Field2 (-75 0 0)(Abs) (pb).txt','E-Field2 (-75 0 0)(X) (pb).txt','E-Field2 (-75 0 0)(Y) (pb).txt','E-Field2 (-75 0 0)(Z) (pb).txt']

# f domain filenames

# %%
data = pnd.DataFrame(columns=['E1_abs','E1_x','E1_y','E1_z','E2_abs','E2_x','E2_y','E2_z'])

# %%
# load time-domain
data = pnd.DataFrame()

for k in range(len(folders)):
    file_path = fpath+folders[k]+field_path

    temp = { 'E1_abs': [np.loadtxt(file_path+f_comp[0], delimiter='\t', skiprows=header_len)],
            'E1_x': [np.loadtxt(file_path+f_comp[1], delimiter='\t', skiprows=header_len)],
            'E1_y': [np.loadtxt(file_path+f_comp[2], delimiter='\t', skiprows=header_len)],
            'E1_z': [np.loadtxt(file_path+f_comp[3], delimiter='\t', skiprows=header_len)],
            'E2_abs': [np.loadtxt(file_path+f_comp[4], delimiter='\t', skiprows=header_len)],
            'E2_x': [np.loadtxt(file_path+f_comp[5], delimiter='\t', skiprows=header_len)],
            'E2_y': [np.loadtxt(file_path+f_comp[6], delimiter='\t', skiprows=header_len)],
            'E2_z': [np.loadtxt(file_path+f_comp[7], delimiter='\t', skiprows=header_len)]
    }

    data = data.append(pnd.DataFrame(temp, index=[folders[k]]))

# %%
# load time-domain
data_f = pnd.DataFrame()

for k in range(len(folders)):
    file_path = fpath+folders[k]

    temp = { 'E1_abs': [np.loadtxt(file_path+f_comp[0], delimiter='\t', skiprows=header_len)],
            'E1_x': [np.loadtxt(file_path+f_comp[1], delimiter='\t', skiprows=header_len)],
            'E1_y': [np.loadtxt(file_path+f_comp[2], delimiter='\t', skiprows=header_len)],
            'E1_z': [np.loadtxt(file_path+f_comp[3], delimiter='\t', skiprows=header_len)],
            'E2_abs': [np.loadtxt(file_path+f_comp[4], delimiter='\t', skiprows=header_len)],
            'E2_x': [np.loadtxt(file_path+f_comp[5], delimiter='\t', skiprows=header_len)],
            'E2_y': [np.loadtxt(file_path+f_comp[6], delimiter='\t', skiprows=header_len)],
            'E2_z': [np.loadtxt(file_path+f_comp[7], delimiter='\t', skiprows=header_len)]
    }

    data_f = data_f.append(pnd.DataFrame(temp, index=[folders[k]]))

# %%
data
# Out:
#                                                                                         E1_abs  \
# prism_10mm_side_50mm_behind_7cell/           [[0.0, 0.0], [0.00013802273, 0.0], [0.00027604...
# prism_20mm_side_25mmbehind_50mmfront_7cell/  [[0.0, 0.0], [0.00013802751, 0.0], [0.00027605...
# prism_20mm_side_25mmbehind_7cell/            [[0.0, 0.0], [0.00013802695, 0.0], [0.00027605...
# prism_20mm_side_50mmbehind_7cell/            [[0.0, 0.0], [0.00013802545, 0.0], [0.00027605...
# prism_20mm_side_50mmbehind_7cell-1.5mm/      [[0.0, 0.0], [0.00013706279, 0.0], [0.00027412...
# prism_20mm_side_50mmbehind_7cell-n1.5mm/     [[0.0, 0.0], [0.0001370356, 0.0], [0.000274071...
#
#                                                                                           E1_x  \
# prism_10mm_side_50mm_behind_7cell/           [[0.0, 0.0], [0.00013802273, 0.0], [0.00027604...
# prism_20mm_side_25mmbehind_50mmfront_7cell/  [[0.0, 0.0], [0.00013802751, 0.0], [0.00027605...
# ...

# %% [markdown]
# # Effect of the vacuum increase on the side

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_abs'].loc['prism_10mm_side_50mm_behind_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_10mm_side_50mm_behind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_10mm_side_50mm_behind_7cell')

xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')

ax.legend(frameon=True)
ax.set_title('Side vacuum')
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_abs [kV/m]')
ax.set_xlim(0.2,)

plt.savefig('side_abs.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_x'].loc['prism_10mm_side_50mm_behind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_10mm_side_50mm_behind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_10mm_side_50mm_behind_7cell')

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')

ax.legend(frameon=True)
ax.set_title('Side vacuum')
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_x [kV/m]')
ax.set_xlim(0.2,)

plt.savefig('side_x.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_z'].loc['prism_10mm_side_50mm_behind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_10mm_side_50mm_behind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_10mm_side_50mm_behind_7cell')

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')

ax.legend(frameon=True)
ax.set_title('Side vacuum')
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_z [kV/m]')
ax.set_xlim(0.2,)

plt.savefig('side_z.png',format='png')

# %% [markdown]
# # Effect of the vacuum before the prism

# %%
offset = 0.274-0.19

# %%
fig, ax = plt.subplots(1, dpi=130)
xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]-offset
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')



xx = data['E1_abs'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')


ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_abs [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('behind_abs.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_x'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]-offset
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')

ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_x [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('behind_x.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]-offset
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell')

ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_z [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('behind_z.png',format='png')

# %% [markdown]
# # Effect of the vacuum after the prism

# %%
fig, ax = plt.subplots(1, dpi=130)
xx = data['E1_abs'].loc['prism_20mm_side_25mmbehind_50mmfront_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_25mmbehind_50mmfront_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_50mmfront_7cell')



xx = data['E1_abs'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')


ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_abs [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('front_abs.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_x'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')

xx = data['E1_x'].loc['prism_20mm_side_25mmbehind_50mmfront_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_25mmbehind_50mmfront_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_50mmfront_7cell')

ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_x [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('front_x.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')

xx = data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_25mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_25mmbehind_7cell')

ax.legend(frameon=True)
ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_z [kV/m]')
ax.set_xlim(0.1,)

plt.savefig('front_z.png',format='png')

# %% [markdown]
# # Beam movement effect
#
# 5mm hole
# Beam in centre and +/- 1.5 mm

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_abs [kV/m]')
ax[0].set_xlim(0.25,.45)

xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_abs [kV/m]')
ax[1].set_xlim(0.25,.45)

plt.tight_layout()

plt.savefig('steer_abs.png',format='png')

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_x [kV/m]')
ax[0].set_xlim(0.25,.45)

xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_x [kV/m]')
ax[1].set_xlim(0.25,.45)

plt.tight_layout()

plt.savefig('steer_x.png',format='png')

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_z [kV/m]')
ax[0].set_xlim(0.25,.45)

xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')

xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')

xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_z [kV/m]')
ax[1].set_xlim(0.25,.45)

plt.tight_layout()

plt.savefig('steer_z.png',format='png')

# %% [markdown]
# # Delta sigma

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
# electrode 1
xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E1_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_zero = np.abs((np.max(yy)) - (np.min(yy)))

# electrode2
xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E2_abs'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_zero = np.abs((np.max(yy)) - (np.min(yy)))

ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_z [kV/m]')
ax[0].set_xlim(0.25,.45)

ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_z [kV/m]')
ax[1].set_xlim(0.25,.45)

elecabs_1 = np.array([d1_pos, d1_zero, d1_neg])
elecabs_2 = np.array([d2_pos, d2_zero, d2_neg])

ax[1].legend(frameon=True)
ax[1].set_xlabel('Displacement [mm]')
ax[1].set_ylabel('Delta signal [V]')
# ax[1].set_xlim(0.25,.45)

plt.tight_layout()
# Out:
# 23.827729
# 0.0
#
# 88.436786
# 0.0
#
# 44.496857000000006
# 0.0
#
# 88.440053
# 0.0
#
# 23.81959
# 0.0
#
# 44.497809000000004
# 0.0

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
# electrode 1
xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_zero = np.abs((np.max(yy)) - (np.min(yy)))

# electrode2
xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E2_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_zero = np.abs((np.max(yy)) - (np.min(yy)))

ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_z [kV/m]')
ax[0].set_xlim(0.25,.45)

ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_z [kV/m]')
ax[1].set_xlim(0.25,.45)

elecz_1 = np.array([d1_pos, d1_zero, d1_neg])
elecz_2 = np.array([d2_pos, d2_zero, d2_neg])

ax[1].legend(frameon=True)
ax[1].set_xlabel('Displacement [mm]')
ax[1].set_ylabel('Delta signal [V]')
# ax[1].set_xlim(0.25,.45)

plt.tight_layout()
# Out:
# 18.940665000000003
# -5.2907744
#
# 69.80032000000001
# -55.044846
#
# 35.50206
# -14.728584999999999
#
# 69.798551
# -54.996658000000004
#
# 18.925528
# -5.2883106
#
# 35.502871
# -14.72952

# %%
fig, ax = plt.subplots(1,2, dpi=130, figsize=(10,5))
# electrode 1
xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[0].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d1_zero = np.abs((np.max(yy)) - (np.min(yy)))

# electrode2
xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- +1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_pos = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,0][:3000]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell-n1.5mm/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell- -1.5mm/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_neg = np.abs((np.max(yy)) - (np.min(yy)))

xx = data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0][:3000]
yy = 1e-3*data['E2_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1][:3000]
ax[1].plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')
print(np.max(yy))
print(np.min(yy))
print(' ')
d2_zero = np.abs((np.max(yy)) - (np.min(yy)))

ax[0].legend(frameon=True)
ax[0].set_xlabel('Time [ps]')
ax[0].set_ylabel('E1_x [kV/m]')
ax[0].set_xlim(0.25,.45)

ax[1].legend(frameon=True)
ax[1].set_xlabel('Time [ps]')
ax[1].set_ylabel('E2_z [kV/m]')
ax[1].set_xlim(0.25,.45)

elecx_1 = np.array([d1_pos, d1_zero, d1_neg])
elecx_2 = np.array([d2_pos, d2_zero, d2_neg])
# Out:
# 17.703901000000002
# -7.1452157
#
# 54.588139000000005
# -59.553110000000004
#
# 27.046901000000002
# -15.876796
#
# 59.465452
# -54.552241
#
# 7.148954300000001
# -17.705523000000003
#
# 15.877583000000001
# -27.047485

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = np.array([-1.5, 0., 1.5])
yy = elecx_1-elecx_2
ax.plot(xx, yy, 'o', label='E_x')

yy = elecz_1-elecz_2
ax.plot(xx, yy, 'o', label='E_z')

yy = elecabs_1-elecabs_2
ax.plot(xx, yy, 'o', label='E_abs')

ax.set_xlabel('Beam displacement [mm]')
ax.set_ylabel('Delta signal [kV/m]')
ax.legend(frameon=True)

plt.savefig('Delta_signal.png', format="png")

# %%
fig, ax = plt.subplots(1, dpi=130)

xx = np.array([-1.5, 0., 1.5])
yy = (elecx_1-elecx_2)/(elecx_1+elecx_2)
ax.plot(xx, yy, 'o', label='E_x')

yy = (elecz_1-elecz_2)/(elecz_1+elecz_2)
ax.plot(xx, yy, 'o', label='E_z')

yy = (elecabs_1-elecabs_2)/(elecabs_1+elecabs_2)
ax.plot(xx, yy, 'o', label='E_abs')

ax.set_xlabel('Beam displacement [mm]')
ax.set_ylabel('Delta/Sigma signal ')
ax.legend(frameon=True)
plt.savefig('Delta_sigma_signal.png', format="png")

# %% [markdown]
# # Plot details

# %%
fig, ax = plt.subplots(1, dpi=130, figsize=(5,3))

xx = data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_x [kV/m]')
ax.set_xlim(0.32,.46)
ax.set_ylim(-20,+30)


plt.tight_layout()

plt.savefig('steer_x_zoom.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130, figsize=(5,3))

xx = data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data['E1_z'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, yy, label='prism_20mm_side_50mmbehind_7cell centre/')


ax.set_xlabel('Time [ps]')
ax.set_ylabel('E1_z [kV/m]')
ax.set_xlim(0.32,.46)
ax.set_ylim(-20,+40)


plt.tight_layout()

plt.savefig('steer_z_zoom.png',format='png')

# %%
fig, ax = plt.subplots(1, dpi=130, figsize=(5,3))

xx = data_f['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,0]
yy = 1e-3*data_f['E1_x'].loc['prism_20mm_side_50mmbehind_7cell/'][:,1]
ax.plot(xx, 20*np.log10(yy), label='prism_20mm_side_50mmbehind_7cell centre/')


ax.set_xlabel('Frequency [GHz]')
ax.set_ylabel('Magnitude [dB]')
ax.set_xlim(0,100)
# ax.set_ylim(-20,+30)


plt.tight_layout()

plt.savefig('steer_x_zoom_freq.png',format='png')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in log10
#   """
